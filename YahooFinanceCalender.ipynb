# %%
import datetime
from yahoo_earnings_calendar import YahooEarningsCalendar

date_from = datetime.datetime.strptime(
    'May 1 2021', '%b %d %Y')
date_to = datetime.datetime.strptime(
    'May 31 2021', '%b %d %Y')
yec_may = YahooEarningsCalendar()

# %%
df_date = yec_may.earnings_between(date_from,  date_to)

# %%
import pandas as pd
import time

list_ticker = []
# list_companyshortname =[]
# list_startdatetime =[]
# list_startdatetimetype =[]
# list_epsestimate =[]
# list_epsactual =[]
# list_epssurprisepct =[]
# list_timeZoneShortName =[]
# list_gmtOffsetMilliSeconds =[]
# list_quoteType =[]

df= pd.DataFrame() 
    df['Ticker'] = [comp['Ticker'] for comp in df_may]
    list_ticker.append(df_may[comp]['ticker'])
#     list_ticker.append(df_jun[comp]['ticker'])
#     list_ticker.append(df_jul[comp]['ticker'])
    if comp%20 == 0:
        time.sleep(1)
#     list_companyshortname.append(df_to_be_dict[comp]['companyshortname'])
#     list_startdatetime.append(df_to_be_dict[comp]['startdatetime'])
#     list_startdatetimetype.append(df_to_be_dict[comp]['startdatetimetype'])
#     list_epsestimate.append(df_to_be_dict[comp]['epsestimate'])
#     list_epsactual.append(df_to_be_dict[comp]['epsactual'])
#     list_epssurprisepct.append(df_to_be_dict[comp]['epssurprisepct'])
#     list_timeZoneShortName.append(df_to_be_dict[comp]['timeZoneShortName'])
#     list_gmtOffsetMilliSeconds.append(df_to_be_dict[comp]['gmtOffsetMilliSeconds'])
#     list_quoteType.append(df_to_be_dict[comp]['quoteType'])

# %%
import pandas as pd
df= pd.DataFrame() 
df['ticker_2'] = [may['ticker'] for may in df_may]
df.head()
# Out:
#   ticker_2
# 0     TURN
# 1      GPI
# 2     AQST
# 3     RYAM
# 4      AIG

# %%
df = pd.DataFrame()
df['Ticker'] = list_ticker
# df['Companyshortname'] = list_companyshortname
# df['Startdatetime'] = list_startdatetime 
# df['Startdatetimetype'] = list_startdatetimetype
# df['Epsestimate'] = list_epsestimate 
# df['Epsactual'] = list_epsactual
# df['Epssurprisepct'] = list_epssurprisepct
# df['TimeZoneShortName'] = list_timeZoneShortName
# df['GmtOffsetMilliSeconds'] = list_gmtOffsetMilliSeconds
# df['QuoteType'] = list_quoteType
df.shape
# Out:
# (1539, 10)

# %%
df.head(50)
# Out:
#    Ticker                          Companyshortname             Startdatetime  \
# 0    TURN                   180 Degree Capital Corp  2021-05-03T10:59:00.000Z
# 1     GPI                    Group 1 Automotive Inc  2021-05-03T12:30:00.000Z
# 2    AQST                Aquestive Therapeutics Inc  2021-05-03T20:00:00.000Z
# 3    RYAM           Rayonier Advanced Materials Inc  2021-05-03T10:59:00.000Z
# 4     AIG          American International Group Inc  2021-05-03T10:59:00.000Z
# 5     AXS                 AXIS Capital Holdings Ltd  2021-05-03T10:59:00.000Z
# 6     AOS                          A. O. Smith Corp  2021-05-03T12:30:00.000Z
# 7     ASH              Ashland Global Holdings Inc.  2021-05-03T10:59:00.000Z
# 8    ATVI                   Activision Blizzard Inc  2021-05-03T10:59:00.000Z
# 9    AXTA                Axalta Coating Systems Ltd  2021-05-03T10:59:00.000Z
# 10    ABG               Asbury Automotive Group Inc  2021-05-03T12:30:00.000Z
# ...

# %%
import datetime
import pandas as pd
import numpy as np
from yahoo_earnings_calendar import YahooEarningsCalendar
#############################################################


date_from = datetime.datetime.strptime('Jun 1 2021', '%b %d %Y')
date_to = datetime.datetime.strptime('Jun 10 2021', '%b %d %Y')
yec = YahooEarningsCalendar()



for comp in range(len(df_to_be_dict)):
    df_to_be_dict = yec.earnings_between(date_from,  date_to)
    list_ticker.append(df_to_be_dict[comp]['ticker'])
    list_companyshortname.append(df_to_be_dict[comp]['companyshortname'])
    list_startdatetime.append(df_to_be_dict[comp]['startdatetime'])
    list_startdatetimetype.append(df_to_be_dict[comp]['startdatetimetype'])
    list_epsestimate.append(df_to_be_dict[comp]['epsestimate'])
    list_epsactual.append(df_to_be_dict[comp]['epsactual'])
    list_epssurprisepct.append(df_to_be_dict[comp]['epssurprisepct'])
    list_timeZoneShortName.append(df_to_be_dict[comp]['timeZoneShortName'])
    list_gmtOffsetMilliSeconds.append(df_to_be_dict[comp]['gmtOffsetMilliSeconds'])
    list_quoteType.append(df_to_be_dict[comp]['quoteType'])
    df['Ticker'] = list_ticker
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-6f5d871244c7> in <module>
#      24     list_gmtOffsetMilliSeconds.append(df_to_be_dict[comp]['gmtOffsetMilliSeconds'])
#      25     list_quoteType.append(df_to_be_dict[comp]['quoteType'])
# ---> 26     df['Ticker'] = list_ticker
#
# c:\users\thoma\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# c:\users\thoma\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
# ...

# %%
import datetime

start_date = datetime.datetime.strptime('May 1 2021', '%b %d %Y')
number_of_days = 5

date_list = [(start_date + datetime.timedelta(days = day)).strptime() for day in range(number_of_days)]
date_list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-a0ab85bf213a> in <module>
#       4 number_of_days = 5
#       5
# ----> 6 date_list = [(start_date + datetime.timedelta(days = day)).strptime() for day in range(number_of_days)]
#       7 date_list
#
# <ipython-input-10-a0ab85bf213a> in <listcomp>(.0)
#       4 number_of_days = 5
#       5
# ----> 6 date_list = [(start_date + datetime.timedelta(days = day)).strptime() for day in range(number_of_days)]
#       7 date_list
#
# TypeError: strptime() takes exactly 2 arguments (0 given)
